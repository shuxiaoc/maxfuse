# %%
import sys
sys.path
# Out:
# ['/home/mnt/nzh/nzhanglab/project/shuang/scATAC/comparison_methods/scglue',
#  '/usr/local/python-3.8.5/lib/python38.zip',
#  '/usr/local/python-3.8.5/lib/python3.8',
#  '/usr/local/python-3.8.5/lib/python3.8/lib-dynload',
#  '',
#  '/home/stat/shuang91/gpuenv385/lib/python3.8/site-packages',
#  '/home/stat/shuang91/gpuenv385/lib/python3.8/site-packages/stereoscope-0.3.1-py3.8.egg']

# %%
sys.path.append('/home/mnt/nzh/nzhanglab/project/shuang/miniconda3/envs/scglue2/lib/python3.8/site-packages')

# %%
import anndata
import networkx as nx
import scanpy as sc
import scglue
from matplotlib import rcParams

# %%
rna = anndata.read_h5ad("pbmc/pbmc_RNA_v2.h5ad")
rna
# Out:
# AnnData object with n_obs × n_vars = 7790 × 36601
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'celltype', 'domain'
#     var: 'features'

# %%
atac = anndata.read_h5ad("pbmc/pbmc_ATAC_v2.h5ad")
atac
# Out:
# AnnData object with n_obs × n_vars = 7790 × 106056
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'celltype', 'domain'
#     var: 'features'

# %%
rna.X, rna.X.data
# Out:
# (<7790x36601 sparse matrix of type '<class 'numpy.float64'>'
#  	with 15530567 stored elements in Compressed Sparse Row format>,
#  array([ 1.,  1.,  1., ...,  1., 22.,  1.]))

# %%
rna.layers["counts"] = rna.X.copy()

# %%
sc.pp.highly_variable_genes(rna, n_top_genes=2000, flavor="seurat_v3")

# %%
sc.pp.normalize_total(rna)
sc.pp.log1p(rna)
sc.pp.scale(rna)
sc.tl.pca(rna, n_comps=100, svd_solver="auto")

# %%
sc.pp.neighbors(rna, metric="cosine")
sc.tl.umap(rna)
sc.pl.umap(rna, color="celltype")
# Out:
# /home/stat/shuang91/gpuenv385/lib/python3.8/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'domain' as categorical

# %%
atac.X, atac.X.data
# Out:
# (<7790x106056 sparse matrix of type '<class 'numpy.float64'>'
#  	with 61073586 stored elements in Compressed Sparse Row format>,
#  array([1., 2., 2., ..., 2., 2., 2.]))

# %%
scglue.data.lsi(atac, n_components=100, n_iter=15)
# Out:
# /home/stat/shuang91/gpuenv385/lib/python3.8/site-packages/sklearn/utils/extmath.py:368: FutureWarning: If 'random_state' is not supplied, the current default is to use 0 as a fixed seed. This will change to  None in version 1.2 leading to non-deterministic results that better reflect nature of the randomized_svd solver. If you want to silence this warning, set 'random_state' to an integer seed or to None explicitly depending if you want your code to be deterministic or not.
#   warnings.warn(

# %%
sc.pp.neighbors(atac, use_rep="X_lsi", metric="cosine")
sc.tl.umap(atac)

# %%
sc.pl.umap(atac, color="celltype")
# Out:
# /home/stat/shuang91/gpuenv385/lib/python3.8/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'domain' as categorical

# %%
rna.var.head()
# Out:
#                 features  highly_variable  highly_variable_rank     means  \
# MIR1302-2HG  MIR1302-2HG            False                   NaN  0.000000
# FAM138A          FAM138A            False                   NaN  0.000000
# OR4F5              OR4F5            False                   NaN  0.000000
# AL627309.1    AL627309.1            False                   NaN  0.007959
# AL627309.3    AL627309.3            False                   NaN  0.000000
#
#              variances  variances_norm      mean      std
# MIR1302-2HG    0.00000         0.00000  0.000000  1.00000
# FAM138A        0.00000         0.00000  0.000000  1.00000
# OR4F5          0.00000         0.00000  0.000000  1.00000
# AL627309.1     0.00918         0.98622  0.004634  0.05598
# AL627309.3     0.00000         0.00000  0.000000  1.00000

# %%
rna.var_names.name = 'genes'

# %%
rna.var_names
# Out:
# Index(['MIR1302-2HG', 'FAM138A', 'OR4F5', 'AL627309.1', 'AL627309.3',
#        'AL627309.2', 'AL627309.5', 'AL627309.4', 'AP006222.2', 'AL732372.1',
#        ...
#        'AC133551.1', 'AC136612.1', 'AC136616.1', 'AC136616.3', 'AC136616.2',
#        'AC141272.1', 'AC023491.2', 'AC007325.1', 'AC007325.4', 'AC007325.2'],
#       dtype='object', name='genes', length=36601)

# %%
scglue.data.get_gene_annotation(
    rna, gtf="gencode.v40.chr_patch_hapl_scaff.annotation.gtf.gz",
    gtf_by="gene_name"
)
rna.var.loc[:, ["chrom", "chromStart", "chromEnd"]].head()
# Out:
#             chrom  chromStart  chromEnd
# genes
# MIR1302-2HG  chr1     29553.0   31109.0
# FAM138A      chr1     34553.0   36081.0
# OR4F5        chr1     65418.0   71585.0
# AL627309.1    NaN         NaN       NaN
# AL627309.3    NaN         NaN       NaN

# %%
rna.var
# Out:
#                 features  highly_variable  highly_variable_rank     means  \
# genes
# MIR1302-2HG  MIR1302-2HG            False                   NaN  0.000000
# FAM138A          FAM138A            False                   NaN  0.000000
# OR4F5              OR4F5            False                   NaN  0.000000
# AL627309.1    AL627309.1            False                   NaN  0.007959
# AL627309.3    AL627309.3            False                   NaN  0.000000
# ...                  ...              ...                   ...       ...
# AC141272.1    AC141272.1            False                   NaN  0.000000
# AC023491.2    AC023491.2            False                   NaN  0.000000
# AC007325.1    AC007325.1            False                   NaN  0.000513
# AC007325.4    AC007325.4            False                   NaN  0.005006
# AC007325.2    AC007325.2            False                   NaN  0.000000
#
#              variances  variances_norm      mean       std chrom  chromStart  \
# genes
# MIR1302-2HG   0.000000        0.000000  0.000000  1.000000  chr1     29553.0
# FAM138A       0.000000        0.000000  0.000000  1.000000  chr1     34553.0
# OR4F5         0.000000        0.000000  0.000000  1.000000  chr1     65418.0
# AL627309.1    0.009180        0.986220  0.004634  0.055980   NaN         NaN
# AL627309.3    0.000000        0.000000  0.000000  1.000000   NaN         NaN
# ...                ...             ...       ...       ...   ...         ...
# AC141272.1    0.000000        0.000000  0.000000  1.000000   NaN         NaN
# AC023491.2    0.000000        0.000000  0.000000  1.000000   NaN         NaN
# AC007325.1    0.000513        0.970248  0.000268  0.012195   NaN         NaN
# AC007325.4    0.005239        0.919366  0.002795  0.042176   NaN         NaN
# AC007325.2    0.000000        0.000000  0.000000  1.000000   NaN         NaN
#
#              ...  thickEnd itemRgb blockCount blockSizes blockStarts  \
# genes        ...
# MIR1302-2HG  ...         .       .          .          .           .
# FAM138A      ...         .       .          .          .           .
# OR4F5        ...         .       .          .          .           .
# AL627309.1   ...       NaN     NaN        NaN        NaN         NaN
# AL627309.3   ...       NaN     NaN        NaN        NaN         NaN
# ...          ...       ...     ...        ...        ...         ...
# AC141272.1   ...       NaN     NaN        NaN        NaN         NaN
# AC023491.2   ...       NaN     NaN        NaN        NaN         NaN
# AC007325.1   ...       NaN     NaN        NaN        NaN         NaN
# AC007325.4   ...       NaN     NaN        NaN        NaN         NaN
# AC007325.2   ...       NaN     NaN        NaN        NaN         NaN
#
#                        gene_id       gene_type     hgnc_id  \
# genes
# MIR1302-2HG  ENSG00000243485.5          lncRNA  HGNC:52482
# FAM138A      ENSG00000237613.2          lncRNA  HGNC:32334
# OR4F5        ENSG00000186092.7  protein_coding  HGNC:14825
# AL627309.1                 NaN             NaN         NaN
# AL627309.3                 NaN             NaN         NaN
# ...                        ...             ...         ...
# AC141272.1                 NaN             NaN         NaN
# AC023491.2                 NaN             NaN         NaN
# AC007325.1                 NaN             NaN         NaN
# AC007325.4                 NaN             NaN         NaN
# AC007325.2                 NaN             NaN         NaN
#
#                       havana_gene         tag
# genes
# MIR1302-2HG  OTTHUMG00000000959.2  ncRNA_host
# FAM138A      OTTHUMG00000000960.1         NaN
# OR4F5        OTTHUMG00000001094.4         NaN
# AL627309.1                    NaN         NaN
# AL627309.3                    NaN         NaN
# ...                           ...         ...
# AC141272.1                    NaN         NaN
# AC023491.2                    NaN         NaN
# AC007325.1                    NaN         NaN
# AC007325.4                    NaN         NaN
# AC007325.2                    NaN         NaN
#
# [36601 rows x 25 columns]

# %%
df = rna.var
#print(df.dropna(subset=['chrom'])["features"])

# %%
rna2 = rna
rna2 = rna2[:,df.dropna(subset=['chrom'])["features"]]

# %%
rna2.var.loc[:, ["chrom", "chromStart", "chromEnd"]]
# Out:
#                   chrom  chromStart  chromEnd
# genes
# MIR1302-2HG        chr1     29553.0   31109.0
# FAM138A            chr1     34553.0   36081.0
# OR4F5              chr1     65418.0   71585.0
# OR4F29             chr1    450739.0  451678.0
# OR4F16             chr1    685715.0  686654.0
# ...                 ...         ...       ...
# MT-ND4             chrM     10759.0   12137.0
# MT-ND5             chrM     12336.0   14148.0
# MT-ND6             chrM     14148.0   14673.0
# MT-CYB             chrM     14746.0   15887.0
# MAFIP        GL000194.1     53593.0  115055.0
#
# [23582 rows x 3 columns]

# %%
rna2.var_names
# Out:
# Index(['MIR1302-2HG', 'FAM138A', 'OR4F5', 'OR4F29', 'OR4F16', 'LINC01409',
#        'FAM87B', 'LINC01128', 'LINC00115', 'FAM41C',
#        ...
#        'MT-ATP8', 'MT-ATP6', 'MT-CO3', 'MT-ND3', 'MT-ND4L', 'MT-ND4', 'MT-ND5',
#        'MT-ND6', 'MT-CYB', 'MAFIP'],
#       dtype='object', name='genes', length=23582)

# %%
#rna2.var.loc[:, ["chrom", "chromStart", "chromEnd"]].to_csv('e18mouse/rnavar2.csv',index=False)

# %%
atac.var_names[:5]
# Out:
# Index(['chr1-10109-10357', 'chr1-180730-181630', 'chr1-191491-191736',
#        'chr1-267816-268196', 'chr1-586028-586373'],
#       dtype='object')

# %%
split = atac.var_names.str.split(r"[:-]")
atac.var["chrom"] = split.map(lambda x: x[0])
atac.var["chromStart"] = split.map(lambda x: x[1])
atac.var["chromEnd"] = split.map(lambda x: x[2])
atac.var.head()
# Out:
#                               features chrom chromStart chromEnd
# chr1-10109-10357      chr1-10109-10357  chr1      10109    10357
# chr1-180730-181630  chr1-180730-181630  chr1     180730   181630
# chr1-191491-191736  chr1-191491-191736  chr1     191491   191736
# chr1-267816-268196  chr1-267816-268196  chr1     267816   268196
# chr1-586028-586373  chr1-586028-586373  chr1     586028   586373

# %%
graph = scglue.genomics.rna_anchored_prior_graph(rna2, atac)
graph
# Out:
#   0%|          | 0/23582 [00:00<?, ?it/s]

# %%
graph.number_of_nodes(), graph.number_of_edges()
# Out:
# (129638, 293002)

# %%
# Graph node covers all omic features
all(graph.has_node(gene) for gene in rna2.var_names), \
all(graph.has_node(peak) for peak in atac.var_names)
# Out:
# (True, True)

# %%
# Edge attributes contain weights and signs
for _, e in zip(range(5), graph.edges):
    print(f"{e}: {graph.edges[e]}")
# Out:
# ('LINC01409', 'chr1-777634-779926', 0): {'dist': 0, 'weight': 1.0, 'sign': 1, 'type': 'fwd'}
# ('LINC01409', 'LINC01409', 0): {'weight': 1.0, 'sign': 1, 'type': 'loop'}
# ('chr1-777634-779926', 'LINC01409', 0): {'dist': 0, 'weight': 1.0, 'sign': 1, 'type': 'rev'}
# ('chr1-777634-779926', 'chr1-777634-779926', 0): {'weight': 1.0, 'sign': 1, 'type': 'loop'}
# ('FAM87B', 'chr1-816881-817647', 0): {'dist': 0, 'weight': 1.0, 'sign': 1, 'type': 'fwd'}

# %%
# Each node has a self-loop
all(graph.has_edge(gene, gene) for gene in rna2.var_names), \
all(graph.has_edge(peak, peak) for peak in atac.var_names)
# Out:
# (True, True)

# %%
# Graph is symmetric
all(graph.has_edge(j, i) for i, j, _ in graph.edges)
# Out:
# True

# %%
atac.var.head()
# Out:
#                               features chrom chromStart chromEnd  \
# chr1-10109-10357      chr1-10109-10357  chr1      10109    10357
# chr1-180730-181630  chr1-180730-181630  chr1     180730   181630
# chr1-191491-191736  chr1-191491-191736  chr1     191491   191736
# chr1-267816-268196  chr1-267816-268196  chr1     267816   268196
# chr1-586028-586373  chr1-586028-586373  chr1     586028   586373
#
#                     highly_variable
# chr1-10109-10357              False
# chr1-180730-181630            False
# chr1-191491-191736            False
# chr1-267816-268196            False
# chr1-586028-586373            False

# %%
rna = rna2

# %%
rna.var
# Out:
#                 features  highly_variable  highly_variable_rank      means  \
# genes
# MIR1302-2HG  MIR1302-2HG            False                   NaN   0.000000
# FAM138A          FAM138A            False                   NaN   0.000000
# OR4F5              OR4F5            False                   NaN   0.000000
# OR4F29            OR4F29            False                   NaN   0.000000
# OR4F16            OR4F16            False                   NaN   0.000000
# ...                  ...              ...                   ...        ...
# MT-ND4            MT-ND4            False                   NaN  35.945443
# MT-ND5            MT-ND5            False                   NaN  14.226059
# MT-ND6            MT-ND6            False                   NaN   0.469448
# MT-CYB            MT-CYB            False                   NaN  35.851476
# MAFIP              MAFIP            False                   NaN   0.006033
#
#               variances  variances_norm      mean       std       chrom  \
# genes
# MIR1302-2HG    0.000000        0.000000  0.000000  1.000000        chr1
# FAM138A        0.000000        0.000000  0.000000  1.000000        chr1
# OR4F5          0.000000        0.000000  0.000000  1.000000        chr1
# OR4F29         0.000000        0.000000  0.000000  1.000000        chr1
# OR4F16         0.000000        0.000000  0.000000  1.000000        chr1
# ...                 ...             ...       ...       ...         ...
# MT-ND4       560.757968        0.871786  3.351059  0.466891        chrM
# MT-ND5       117.938748        0.925498  2.420568  0.548431        chrM
# MT-ND6         0.603188        0.801040  0.250367  0.380165        chrM
# MT-CYB       450.373752        0.703480  3.386630  0.433068        chrM
# MAFIP          0.005998        0.863898  0.003482  0.047882  GL000194.1
#
#              chromStart  ...  thickEnd itemRgb blockCount blockSizes  \
# genes                    ...
# MIR1302-2HG     29553.0  ...         .       .          .          .
# FAM138A         34553.0  ...         .       .          .          .
# OR4F5           65418.0  ...         .       .          .          .
# OR4F29         450739.0  ...         .       .          .          .
# OR4F16         685715.0  ...         .       .          .          .
# ...                 ...  ...       ...     ...        ...        ...
# MT-ND4          10759.0  ...         .       .          .          .
# MT-ND5          12336.0  ...         .       .          .          .
# MT-ND6          14148.0  ...         .       .          .          .
# MT-CYB          14746.0  ...         .       .          .          .
# MAFIP           53593.0  ...         .       .          .          .
#
#             blockStarts            gene_id       gene_type     hgnc_id  \
# genes
# MIR1302-2HG           .  ENSG00000243485.5          lncRNA  HGNC:52482
# FAM138A               .  ENSG00000237613.2          lncRNA  HGNC:32334
# OR4F5                 .  ENSG00000186092.7  protein_coding  HGNC:14825
# OR4F29                .  ENSG00000284733.2  protein_coding  HGNC:31275
# OR4F16                .  ENSG00000284662.2  protein_coding  HGNC:15079
# ...                 ...                ...             ...         ...
# MT-ND4                .  ENSG00000198886.2  protein_coding   HGNC:7459
# MT-ND5                .  ENSG00000198786.2  protein_coding   HGNC:7461
# MT-ND6                .  ENSG00000198695.2  protein_coding   HGNC:7462
# MT-CYB                .  ENSG00000198727.2  protein_coding   HGNC:7427
# MAFIP                 .  ENSG00000274847.1  protein_coding  HGNC:31102
#
#                       havana_gene         tag
# genes
# MIR1302-2HG  OTTHUMG00000000959.2  ncRNA_host
# FAM138A      OTTHUMG00000000960.1         NaN
# OR4F5        OTTHUMG00000001094.4         NaN
# OR4F29       OTTHUMG00000002860.3         NaN
# OR4F16       OTTHUMG00000002581.3         NaN
# ...                           ...         ...
# MT-ND4                        NaN         NaN
# MT-ND5                        NaN         NaN
# MT-ND6                        NaN         NaN
# MT-CYB                        NaN         NaN
# MAFIP                         NaN         NaN
#
# [23582 rows x 25 columns]

# %%
rna2.raw = None

# %%
rna2.raw

# %%
#rna.write("e18mouse/rna_preprocessed.h5ad", compression="gzip")
rna2.write("pbmc/rna_preprocessed_v2.h5ad", compression="gzip")

atac.raw = None
atac.write("pbmc/atac_preprocessed_v2.h5ad", compression="gzip")
nx.write_graphml(graph, "pbmc/prior_v2.graphml.gz")
# Out:
# /home/stat/shuang91/gpuenv385/lib/python3.8/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'chrom' as categorical
# /home/stat/shuang91/gpuenv385/lib/python3.8/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'score' as categorical
# /home/stat/shuang91/gpuenv385/lib/python3.8/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'strand' as categorical
# /home/stat/shuang91/gpuenv385/lib/python3.8/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'thickStart' as categorical
# /home/stat/shuang91/gpuenv385/lib/python3.8/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'thickEnd' as categorical
# /home/stat/shuang91/gpuenv385/lib/python3.8/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'itemRgb' as categorical
# /home/stat/shuang91/gpuenv385/lib/python3.8/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'blockCount' as categorical
# /home/stat/shuang91/gpuenv385/lib/python3.8/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'blockSizes' as categorical
# /home/stat/shuang91/gpuenv385/lib/python3.8/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'blockStarts' as categorical
# /home/stat/shuang91/gpuenv385/lib/python3.8/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'gene_type' as categorical
# /home/stat/shuang91/gpuenv385/lib/python3.8/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'hgnc_id' as categorical
# /home/stat/shuang91/gpuenv385/lib/python3.8/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'havana_gene' as categorical
# /home/stat/shuang91/gpuenv385/lib/python3.8/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'tag' as categorical
# /home/stat/shuang91/gpuenv385/lib/python3.8/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'chrom' as categorical
# /home/stat/shuang91/gpuenv385/lib/python3.8/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'chromStart' as categorical
# /home/stat/shuang91/gpuenv385/lib/python3.8/site-packages/anndata/_core/anndata.py:1228: FutureWarning: The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.
#   c.reorder_categories(natsorted(c.categories), inplace=True)
# ... storing 'chromEnd' as categorical
